# %%
import pandas as pd
import datetime
from datetime import timedelta,date
data=pd.read_excel('amz_info.xlsx')
sku_date=pd.read_excel('sku_list.xlsx')
sku_list=sku_date['sku'].to_list()
data['日期']=pd.to_datetime(data['日期'],format='%Y-%m-%d')

data['排名']=data['排名'].str.replace(',','')
data=data.fillna({'排名':9999})
data['排名']=data['排名'].astype('int64')
data['FBA库存数量']=data['FBA库存数量'].str.replace('>','')
data['日期']=pd.to_datetime(data['日期'],format='%Y/%m%d')

# %%
n=2 #近N日的时间
tm=(date.today()-timedelta(days=n)).strftime("%Y-%m-%d")
def rank_trend(sku):
    data_2=data[(data['ASIN']==sku)]
    data_2=data_2[data_2['日期']>=tm]
    data_2=data_2.set_index('日期')
    r_list=data_2['排名'].tolist()
    sss=''
    for r_v in r_list:
        sss=sss+str(r_v)+'→'
    
    data_1['近3日排名走势'].loc[sku]=sss

# %%
data3=data[(data['日期']=='2022-06-22')].groupby(by=['ASIN']).last()
data4=data3.nsmallest(30,'排名') #前30名
s_list=[data4['日期'],data4['时间'],data4['卖家'],data4['规格'],data4['价格'],data4['发货'],data4['FBA库存数量'],data4['评论数'],data4['评分'],data4['排名']]
data_1=pd.concat(s_list,axis=1)
data_1['近3日排名走势']=''
skus=data_1.index.tolist()
for sku in skus:
    rank_trend(sku)
data_1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3292\2085612626.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['近3日排名走势'].loc[sku]=sss
#                    日期        时间             卖家    规格         价格   发货  \
# ASIN
# B09PV66S6B 2022-06-22  15:21:38   OLYLO Direct  None  $3,299.00  FBA
# B09M8CTWBG 2022-06-22  15:14:45       MWE Tech  None  $2,499.00  FBA
# B09PV82YL6 2022-06-22  15:32:26   OLYLO Direct  None  $2,380.00  FBA
# B09PFVTTJP 2022-06-22  15:22:47       MWE Tech  None  $3,299.00  FBA
# B09TSY3NKQ 2022-06-22  15:29:39   OLYLO Direct  None  $2,199.00  FBA
# B09N166GM8 2022-06-22  15:18:01          WAHER  None  $2,199.00  FBA
# B09M8BDXK9 2022-06-22  15:29:05       MWE Tech  None  $2,799.00  FBM
# B09SV5GYD4 2022-06-22  15:21:55  YC technology  None  $2,399.00  FBA
# B09KRJV89C 2022-06-22  15:26:51       MWE Tech  None  $2,199.00  FBA
# B09PYJ8DSD 2022-06-22  15:31:02     AchhaGo US  None  $2,199.00  FBA
# B09PV7YBP1 2022-06-22  15:13:37   OLYLO Direct  None  $2,799.00  FBA
# B09KRL1DJR 2022-06-22  15:19:11       MWE Tech  None  $2,399.00  FBA
# B09Z2W2927 2022-06-22  15:20:06   OLYLO Direct  None  $2,499.00  FBA
# B09N14N3W1 2022-06-22  15:28:18          WAHER  None  $2,399.00  FBA
# B09PBH2HSB 2022-06-22  15:12:26       MWE Tech  None  $2,999.00  FBA
# B09M8CTWBG   184→204→220→239→247→256→70→61→58→67→45→62→57→37→
# B09PV82YL6  58→92→115→61→72→175→187→218→241→245→257→262→13...
# B09PFVTTJP  353→355→354→357→360→361→361→368→373→369→370→37...
# B09TSY3NKQ  477→482→484→482→484→485→487→485→489→489→489→49...
# B09N166GM8  364→367→372→382→385→389→390→395→399→399→403→40...
# B09M8BDXK9  157→161→181→189→196→48→38→44→42→46→64→80→129→146→
# B09SV5GYD4  179→198→210→218→228→232→235→250→267→268→276→28...
# B09KRJV89C    159→166→59→46→54→76→96→66→59→65→88→106→154→172→
# B09PYJ8DSD  120→134→149→64→74→87→109→154→178→187→75→102→16...
# B09PV7YBP1  206→213→227→232→69→88→113→87→128→130→147→164→2...
# B09KRL1DJR  171→173→191→198→206→207→215→52→60→148→169→185→...
# B09Z2W2927  307→312→321→103→125→148→163→75→146→150→172→190...
# B09N14N3W1  134→149→168→67→208→220→69→133→169→176→192→205→...
# B09PBH2HSB  536→88→136→153→163→185→198→227→250→256→268→276...
# B09SV53Z57  151→165→187→217→230→246→256→275→296→300→311→32...
# B09SV5GN77  151→165→204→217→230→246→256→275→296→300→311→32...
# B09DY2XB3D  360→365→374→380→384→390→394→399→404→405→410→41...
# B09SV57798  298→302→308→320→326→334→339→455→454→454→456→45...
# B09H5S49MF  540→540→465→468→470→474→474→480→487→488→488→49...
# B09WGLYGMM  540→540→465→468→470→378910→379929→381360→38503...
# B09WH5VPJB  540→540→465→468→470→474→474→480→487→488→488→49...
# B09H5RD4NB  540→540→540→543→544→546→548→554→557→558→560→56...
# B09N12ZX71  541→541→543→544→545→548→550→555→561→563→565→56...
# B09YR34NLP  546→547→550→558→560→565→568→573→576→577→580→58...
# B09MRMX611  1710→1717→1728→1741→1744→1751→1760→1770→258→29...
# B09MRN5Y2Y  697→720→757→776→785→802→833→879→334→362→416→47...
# B09PNGKWKN  603→602→603→605→606→610→611→619→620→620→621→62...
# B09V7Q3ZVF  622→622→623→625→626→627→629→636→637→638→640→64...
# B09JG93M6L  654→654→654→654→654→655→655→655→654→654→653→65...

# %%
data_1['近3日排名走势']=''
data_1['近3日排名走势'].loc[sku]=sss
data_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <module>
#       1 data_1['近3日排名走势']=''
# ----> 2 data_1['近3日排名走势'].loc[sku]=sss
#       3 data_1
#
# NameError: name 'sss' is not defined

# %%
#MEW系主号小号当前最新类目排名情况
data5=data[data['卖家'].isin(['MWE Tech','WAHER','YC technology'])].groupby(by=['ASIN']).last()
data6=data5.nsmallest(30,'排名')
data6

# %%
#olylo当前最新类目排名前十
data1=data[data['卖家']=='OLYLO Direct'].groupby(by=['ASIN']).last()
data2=data1.nsmallest(10,'排名')
data2
